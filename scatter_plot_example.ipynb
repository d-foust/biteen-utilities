# %%
from os.path import join

import pandas as pd
import tifffile

import biteen_utilities as bu

# %%
help(bu.plot_locs_scatter)
# Out:
# Help on function plot_locs_scatter in module biteen_plots:
#
# plot_locs_scatter(locs_df, coord_cols=('x', 'y'), color_col=None, scale=1, labels=None, image=None, crop=False, figure_props={}, marker_props={}, scalebar_props=None)
#     Parameters
#     ----------
#     marker_props : dict
#         kwargs to matplotlib.pyplot.scatter
#
#     Returns
#     -------

# %%
locs_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Flagella\DK1362\2023-06-22_DK1362_2channel\007-009\2023-09-22 dstorm_palmari_pipeline"
locs_fname = r"2023-06-22_DK1362_2channel_008_lower_left.locs"

locs_data = pd.read_csv(join(locs_folder, locs_fname), index_col=0)

# %%
locs_data
# Out:
#       index  equivalent_diameter_area  centroid_weighted-0  \
# 0         4                  3.568248            88.306836
# 1         6                  3.191538           103.556761
# 2         7                  4.652426           107.936987
# 3         3                  2.523133            85.809381
# 4         4                  4.513517            88.526293
# ...     ...                       ...                  ...
# 4961      0                  2.985411             8.908313
# 4962      1                  2.523133            47.265152
# 4963      2                  3.191538            92.191176
# 4964      1                  2.523133            62.268499
# 4965      3                  2.523133            90.986523
#
#       centroid_weighted-1  eccentricity          y          x  frame  \
# 0              125.078299      0.797407  10.696805  15.047692      0
# 1               22.782642      0.747103  12.521928   2.824022      0
# ...

# %%
phase_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Flagella\DK1362\2023-06-22_DK1362_2channel\007-009"
phase_fname = r"2023-06-22_DK1362_2channel_009_average_lower_left.tif"

phase_image = tifffile.imread(join(phase_folder, phase_fname))
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'

# %%
bu.plot_locs_scatter(locs_data,
                     figure_props={'figsize': (8,8)},
                     image=phase_image,
                     scale=1/0.05)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %%
from os.path import join

import pandas as pd
import tifffile

import biteen_utilities as bu
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\djfoust\Documents\Python Scripts\biteen_utilities\examples\scatter_plot_example.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/djfoust/Documents/Python%20Scripts/biteen_utilities/examples/scatter_plot_example.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/djfoust/Documents/Python%20Scripts/biteen_utilities/examples/scatter_plot_example.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import tifffile
# ----> <a href='vscode-notebook-cell:/c%3A/Users/djfoust/Documents/Python%20Scripts/biteen_utilities/examples/scatter_plot_example.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import biteen_utilities as bu
#
# ModuleNotFoundError: No module named 'biteen_utilities'

# %%
locs_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Flagella\DK1362\2023-06-22_DK1362_2channel\007-009\2023-09-22 dstorm_palmari_pipeline"
locs_fname = r"2023-06-22_DK1362_2channel_008_lower_left.locs"

locs_data = pd.read_csv(join(locs_folder, locs_fname), index_col=0)

# %%
phase_folder = r"T:\MIGRATED\Lab_Members\Daniel_Foust\Data\Flagella\DK1362\2023-06-22_DK1362_2channel\007-009"
phase_fname = r"2023-06-22_DK1362_2channel_009_average_lower_left.tif"

phase_image = tifffile.imread(join(phase_folder, phase_fname))

# %%
marker_props = {'alpha': 0.5,
                'edgecolors': 'none',
                's': 5,
                # 'c': locs_data['sigma'],
                'c': 'xkcd:hot magenta',
                'vmin': 0.5,
                'vmax': 2.5}

scalebar_props = {'dx': 0.12, # pixel size
                  'units': 'um',
                  'dimension': 'si-length',
                  'frameon': False,
                  'label': None,
                  'scale_loc': 'none',
                  'fixed_value': 2
                  }

# %%
bu.plot_locs_scatter(locs_data,
                     figure_props={'figsize': (8,8)},
                     image=phase_image,
                     scale=1/0.12,
                     marker_props=marker_props,
                     scalebar_props=scalebar_props)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)
